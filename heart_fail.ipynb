# %%
# Import our dependencies
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import seaborn as sns

# %%
#  Import and read the heart.csv.
heart_df = pd.read_csv("data.csv")
heart_df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
#cleaning the dataset by removing all zeroes in the column "cholesterol" as there is no 0 cholesterole.
clean_df=heart_df[heart_df['Cholesterol'] !=0]
clean_df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
clean_df.to_csv("heart.csv", index = False)

# %%
heart_dis=clean_df[(clean_df['HeartDisease'] !=0) & (clean_df['RestingBP'] >=160)]
heart_dis
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 1     49   F           NAP        160          180          0     Normal
# 68    52   M           ASY        160          246          0         ST
# 86    65   M           ASY        170          263          1     Normal
# 93    48   M           ASY        160          329          0     Normal
# 123   58   F           ATA        180          393          0     Normal
# 132   56   M           ASY        170          388          0         ST
# 140   52   M           ASY        160          331          0     Normal
# 142   47   M           ASY        160          291          0         ST
# 185   58   M           NAP        160          211          1         ST
# 189   53   M           ASY        180          285          0         ST
# 221   51   F           ASY        160          303          0     Normal
# 238   48   M           ASY        160          355          0     Normal
# ...

# %%
heart_dis.to_csv("heart-dis.csv", index = False)
